# %% [markdown]
# **1. importation of packages**

# %%
# importation of packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# - Importation of dataset

# %%
data = pd.read_csv("../data/german_credit_data.csv")
data.drop(columns=["Unnamed: 0"], inplace=True)
data.head()
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little              NaN           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    Duration              Purpose  Risk
# 0         6             radio/TV  good
# 1        48             radio/TV   bad
# 2        12            education  good
# 3        42  furniture/equipment  good
# 4        24                  car   bad

# %% [markdown]
# - Description and information of the dataset

# %%
# information
data.info()
# description
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1000 non-null   int64
#  1   Sex               1000 non-null   object
#  2   Job               1000 non-null   int64
#  3   Housing           1000 non-null   object
#  4   Saving accounts   817 non-null    object
#  5   Checking account  606 non-null    object
#  6   Credit amount     1000 non-null   int64
#  7   Duration          1000 non-null   int64
#  8   Purpose           1000 non-null   object
#  9   Risk              1000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 78.3+ KB
#                Age          Job  Credit amount     Duration
# count  1000.000000  1000.000000    1000.000000  1000.000000
# mean     35.546000     1.904000    3271.258000    20.903000
# std      11.375469     0.653614    2822.736876    12.058814
# min      19.000000     0.000000     250.000000     4.000000
# 25%      27.000000     2.000000    1365.500000    12.000000
# 50%      33.000000     2.000000    2319.500000    18.000000
# 75%      42.000000     2.000000    3972.250000    24.000000
# max      75.000000     3.000000   18424.000000    72.000000

# %% [markdown]
# **2. Data cleaning**

# %% [markdown]
# 2.1. Identify missing values

# %%
data.isna().sum()
# Out:
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# Risk                  0
# dtype: int64

# %% [markdown]
# 2.2. Fill the missing values

# %%
# determine the values of each columns which has a missing values
print(data["Checking account"].unique())

print(data["Saving accounts"].unique())
# Out:
# ['little' 'moderate' nan 'rich']
# [nan 'little' 'quite rich' 'rich' 'moderate']

# %%
# fill the missing values (when i detect a missing value in one column on the line and i take a value from the other column from the
# same line to replace it)
data["Saving accounts"] = data["Saving accounts"].fillna(data["Checking account"])
data["Checking account"] = data["Checking account"].fillna(data["Saving accounts"])

# To fill the missing values when the two columns have a missing value on the same line i take the mode of each column
mode_sa = data["Saving accounts"].mode()[0]
mode_ca = data["Checking account"].mode()[0]
data["Saving accounts"] = data["Saving accounts"].fillna(mode_sa)
data["Checking account"] = data["Checking account"].fillna(mode_ca)

data.isna().sum()
# Out:
# Age                 0
# Sex                 0
# Job                 0
# Housing             0
# Saving accounts     0
# Checking account    0
# Credit amount       0
# Duration            0
# Purpose             0
# Risk                0
# dtype: int64

# %% [markdown]
# 2.3. Outlier detection

# %% [markdown]
# Credit Amount

# %%
print(data["Credit amount"].mean())
print(data["Credit amount"].median())
print(data["Credit amount"].mean() - data["Credit amount"].median())
sns.boxplot(data=data, x="Credit amount")
q1 = data["Credit amount"].quantile(0.25)
q3 = data["Credit amount"].quantile(0.75)
iqr = q3 - q1
lower_bound_credit = q1 - 1.5 * iqr
upper_bound_credit = q3 + 1.5 * iqr 
data_outlier_credit = data[(data["Credit amount"] > upper_bound_credit) | (data["Credit amount"] < lower_bound_credit)]
print(len(data_outlier_credit))
print(data_outlier_credit)
# Out:
# 3271.258
# 2319.5
# 951.7579999999998
# 72
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 5     35    male    1    free          little           little           9055
# 17    25    male    2     own          little           little           8072
# 18    44  female    3    free          little         moderate          12579
# 57    31  female    2     own          little           little           9566
# 63    25    male    2     own          little         moderate          14421
# ..   ...     ...  ...     ...             ...              ...            ...
# 927   39    male    2    free          little           little          10297
# 945   30  female    2     own      quite rich         moderate           8358
# 953   26  female    3     own          little           little          10974
# 980   49    male    2     own          little         moderate           8386
# 983   26    male    2     own          little           little           8229
#
#      Duration              Purpose  Risk
# 5          36            education  good
# 17         30             business  good
# 18         24                  car   bad
# 57         36             radio/TV  good
# 63         48             business   bad
# ..        ...                  ...   ...
# 927        48                  car   bad
# 945        48                  car  good
# 953        36  furniture/equipment   bad
# 980        30  furniture/equipment   bad
# 983        36                  car   bad
#
# [72 rows x 10 columns]

# %%
data_credit = data[(data["Credit amount"] <= upper_bound_credit) & (data["Credit amount"] >= lower_bound_credit)]
print(data_credit["Credit amount"].mean())
print(data_credit["Credit amount"].median())
# Out:
# 2676.260775862069
# 2145.5

# %%
# Ajust the outlier values by replace the original value with the bound value
data["Credit amount"] = data["Credit amount"].apply(lambda x:min(max(x, lower_bound_credit),upper_bound_credit))
sns.boxplot(data=data, x="Credit amount")
# Out:
# <Axes: xlabel='Credit amount'>

# %%
# Remove duplicated data
data.duplicated().sum()
data.drop_duplicates(inplace=True)
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# 2.4. Convert categorical data to numeric data

# %%
data_numeric = pd.get_dummies(data, columns=["Sex","Job", "Housing" ,"Saving accounts", "Checking account" ,"Purpose",  "Risk"])
data_numeric.head()
# Out:
#    Age  Credit amount  Duration  Sex_female  Sex_male  Job_0  Job_1  Job_2  \
# 0   67         1169.0         6       False      True  False  False   True
# 1   22         5951.0        48        True     False  False  False   True
# 2   49         2096.0        12       False      True  False   True  False
# 3   45         7882.0        42       False      True  False  False   True
# 4   53         4870.0        24       False      True  False  False   True
#
#    Job_3  Housing_free  ...  Purpose_business  Purpose_car  \
# 0  False         False  ...             False        False
# 1  False         False  ...             False        False
# 2  False         False  ...             False        False
# 3  False          True  ...             False        False
# 4  False          True  ...             False         True
#
#    Purpose_domestic appliances  Purpose_education  \
# 0                        False              False
# 1                        False              False
# 2                        False               True
# 3                        False              False
# 4                        False              False
#
#    Purpose_furniture/equipment  Purpose_radio/TV  Purpose_repairs  \
# 0                        False              True            False
# 1                        False              True            False
# 2                        False             False            False
# 3                         True             False            False
# 4                        False             False            False
#
#    Purpose_vacation/others  Risk_bad  Risk_good
# 0                    False     False       True
# 1                    False      True      False
# 2                    False     False       True
# 3                    False     False       True
# 4                    False      True      False
#
# [5 rows x 30 columns]

# %% [markdown]
# **3.Data analysis**

# %% [markdown]
# Correlation

# %%
# Use a heatmap to visualize the correlation of variable
correlation_matrix = data_numeric.corr()
plt.figure(figsize=(30, 30))
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
correlation_matrix["Risk_bad"]
# Out:
# Age                           -0.089726
# Credit amount                  0.125613
# Duration                       0.213428
# Sex_female                     0.076624
# Sex_male                      -0.076624
# Job_0                          0.006187
# Job_1                         -0.021085
# Job_2                         -0.014753
# Job_3                          0.041248
# Housing_free                   0.082189
# Housing_own                   -0.135745
# Housing_rent                   0.093619
# Saving accounts_little         0.101074
# Saving accounts_moderate      -0.020282
# Saving accounts_quite rich    -0.070643
# Saving accounts_rich          -0.087482
# Checking account_little        0.002179
# Checking account_moderate      0.079595
# Checking account_quite rich   -0.077732
# Checking account_rich         -0.079732
# Purpose_business               0.036675
# Purpose_car                    0.020521
# Purpose_domestic appliances    0.008195
# Purpose_education              0.049527
# Purpose_furniture/equipment    0.021717
# Purpose_radio/TV              -0.106113
# Purpose_repairs                0.021082
# Purpose_vacation/others        0.028259
# Risk_bad                       1.000000
# Risk_good                     -1.000000
# Name: Risk_bad, dtype: float64

# %%
print(correlation_matrix["Risk_good"])
# Out:
# Age                            0.089726
# Credit amount                 -0.125613
# Duration                      -0.213428
# Sex_female                    -0.076624
# Sex_male                       0.076624
# Job_0                         -0.006187
# Job_1                          0.021085
# Job_2                          0.014753
# Job_3                         -0.041248
# Housing_free                  -0.082189
# Housing_own                    0.135745
# Housing_rent                  -0.093619
# Saving accounts_little        -0.101074
# Saving accounts_moderate       0.020282
# Saving accounts_quite rich     0.070643
# Saving accounts_rich           0.087482
# Checking account_little       -0.002179
# Checking account_moderate     -0.079595
# Checking account_quite rich    0.077732
# Checking account_rich          0.079732
# Purpose_business              -0.036675
# Purpose_car                   -0.020521
# Purpose_domestic appliances   -0.008195
# Purpose_education             -0.049527
# Purpose_furniture/equipment   -0.021717
# Purpose_radio/TV               0.106113
# Purpose_repairs               -0.021082
# Purpose_vacation/others       -0.028259
# Risk_bad                      -1.000000
# Risk_good                      1.000000
# Name: Risk_good, dtype: float64

# %%
correlation_matrix
# Out:
#                                   Age  Credit amount  Duration  Sex_female  \
# Age                          1.000000       0.029815 -0.034909   -0.162496
# Credit amount                0.029815       1.000000  0.647182   -0.100504
# Duration                    -0.034909       0.647182  1.000000   -0.080673
# Sex_female                  -0.162496      -0.100504 -0.080673    1.000000
# Sex_male                     0.162496       0.100504  0.080673   -1.000000
# Job_0                        0.059833      -0.041572 -0.043890    0.076273
# Job_1                        0.043232      -0.175325 -0.180741    0.010479
# Job_2                       -0.147623      -0.066939  0.054107    0.008132
# Job_3                        0.127258       0.305653  0.148167   -0.054367
# Housing_free                 0.252850       0.201615  0.189714   -0.101134
# Housing_own                  0.007203      -0.125217 -0.076040   -0.119263
# Housing_rent                -0.213228      -0.015501 -0.063889    0.222606
# Saving accounts_little       0.018654       0.027973 -0.014825    0.012065
# Saving accounts_moderate    -0.067787       0.058425  0.083156   -0.005640
# Saving accounts_quite rich   0.030741      -0.070702 -0.039965   -0.031597
# Saving accounts_rich         0.035639      -0.068323 -0.056661    0.018524
# Checking account_little      0.034457       0.000519 -0.017904   -0.011800
# Checking account_moderate   -0.087839       0.085342  0.076012    0.020731
# Checking account_quite rich  0.035790      -0.053103 -0.020982   -0.037661
# Checking account_rich        0.058069      -0.103226 -0.078008    0.012923
# Purpose_business            -0.002106       0.111633  0.164662   -0.081117
# Purpose_car                  0.101497       0.134085 -0.007092   -0.047009
# Purpose_domestic appliances -0.012681      -0.078247 -0.037103    0.045212
# Purpose_education            0.060169      -0.039719 -0.025157    0.052243
# Purpose_furniture/equipment -0.128215      -0.011161 -0.062270    0.100185
# Purpose_radio/TV            -0.047069      -0.183552 -0.043580   -0.009090
# Purpose_repairs              0.039435      -0.034750 -0.022379   -0.026935
# Purpose_vacation/others      0.042275       0.122301  0.104737   -0.014375
# Risk_bad                    -0.089726       0.125613  0.213428    0.076624
# Risk_good                    0.089726      -0.125613 -0.213428   -0.076624
#
#                              Sex_male     Job_0     Job_1     Job_2     Job_3  \
# Age                          0.162496  0.059833  0.043232 -0.147623  0.127258
# Credit amount                0.100504 -0.041572 -0.175325 -0.066939  0.305653
# Duration                     0.080673 -0.043890 -0.180741  0.054107  0.148167
# Sex_female                  -1.000000  0.076273  0.010479  0.008132 -0.054367
# Sex_male                     1.000000 -0.076273 -0.010479 -0.008132  0.054367
# Job_0                       -0.076273  1.000000 -0.075077 -0.195654 -0.062579
# Job_1                       -0.010479 -0.075077  1.000000 -0.652328 -0.208645
# Job_2                       -0.008132 -0.195654 -0.652328  1.000000 -0.543739
# Job_3                        0.054367 -0.062579 -0.208645 -0.543739  1.000000
# Housing_free                 0.101134  0.035621 -0.109738 -0.033378  0.154265
# Housing_own                  0.119263 -0.040393  0.063341  0.012386 -0.071497
# Housing_rent                -0.222606  0.018818  0.014117  0.012412 -0.040547
# Saving accounts_little      -0.012065 -0.047301  0.010455 -0.030981  0.049877
# Saving accounts_moderate     0.005640  0.033423 -0.011475  0.004754 -0.007344
# Saving accounts_quite rich   0.031597  0.045251 -0.006305  0.019898 -0.038640
# Saving accounts_rich        -0.018524 -0.008087  0.004155  0.030860 -0.043288
# Checking account_little      0.011800 -0.046739 -0.033859  0.052323 -0.013678
# Checking account_moderate   -0.020731  0.032749  0.028918 -0.062510  0.038871
# Checking account_quite rich  0.037661 -0.030647 -0.000102  0.019188 -0.013308
# Checking account_rich       -0.012923  0.049626  0.012201 -0.002980 -0.030194
# Purpose_business             0.081117 -0.003136  0.004905 -0.007519  0.005992
# Purpose_car                  0.047009  0.066419 -0.006710 -0.098962  0.114643
# Purpose_domestic appliances -0.045212  0.046066 -0.032203  0.046513 -0.045983
# Purpose_education           -0.052243 -0.008660  0.033832 -0.018889 -0.008854
# Purpose_furniture/equipment -0.100185 -0.052878 -0.021018  0.064780 -0.042539
# Purpose_radio/TV             0.009090 -0.063270  0.005258  0.086322 -0.097127
# Purpose_repairs              0.026935  0.070438  0.044244 -0.012032 -0.062579
# Purpose_vacation/others      0.014375  0.046066 -0.032203 -0.124738  0.186806
# Risk_bad                    -0.076624  0.006187 -0.021085 -0.014753  0.041248
# Risk_good                    0.076624 -0.006187  0.021085  0.014753 -0.041248
#
#                              Housing_free  ...  Purpose_business  Purpose_car  \
# Age                              0.252850  ...         -0.002106     0.101497
# Credit amount                    0.201615  ...          0.111633     0.134085
# Duration                         0.189714  ...          0.164662    -0.007092
# Sex_female                      -0.101134  ...         -0.081117    -0.047009
# Sex_male                         0.101134  ...          0.081117     0.047009
# Job_0                            0.035621  ...         -0.003136     0.066419
# Job_1                           -0.109738  ...          0.004905    -0.006710
# Job_2                           -0.033378  ...         -0.007519    -0.098962
# Job_3                            0.154265  ...          0.005992     0.114643
# Housing_free                     1.000000  ...         -0.059734     0.127428
# Housing_own                     -0.548368  ...          0.051304    -0.100536
# Housing_rent                    -0.162664  ...         -0.012169     0.015446
# Saving accounts_little           0.022391  ...         -0.052442    -0.007287
# Saving accounts_moderate         0.009074  ...          0.082125     0.025182
# Saving accounts_quite rich      -0.010753  ...         -0.029445    -0.027798
# Saving accounts_rich            -0.045081  ...          0.005325     0.004462
# Checking account_little          0.026879  ...         -0.086339     0.054011
# Checking account_moderate       -0.023018  ...          0.110502    -0.044006
# Checking account_quite rich     -0.005333  ...         -0.032486    -0.026514
# Checking account_rich           -0.005841  ...         -0.006495    -0.004467
# Purpose_business                -0.059734  ...          1.000000    -0.233451
# Purpose_car                      0.127428  ...         -0.233451     1.000000
# Purpose_domestic appliances     -0.038389  ...         -0.036159    -0.078496
# Purpose_education                0.117900  ...         -0.082157    -0.178351
# Purpose_furniture/equipment     -0.071706  ...         -0.154257    -0.334869
# Purpose_radio/TV                -0.109602  ...         -0.204643    -0.444250
# Purpose_repairs                  0.013655  ...         -0.049209    -0.106826
# Purpose_vacation/others          0.079977  ...         -0.036159    -0.078496
# Risk_bad                         0.082189  ...          0.036675     0.020521
# Risk_good                       -0.082189  ...         -0.036675    -0.020521
#
#                              Purpose_domestic appliances  Purpose_education  \
# Age                                            -0.012681           0.060169
# Credit amount                                  -0.078247          -0.039719
# Duration                                       -0.037103          -0.025157
# Sex_female                                      0.045212           0.052243
# Sex_male                                       -0.045212          -0.052243
# Job_0                                           0.046066          -0.008660
# Job_1                                          -0.032203           0.033832
# Job_2                                           0.046513          -0.018889
# Job_3                                          -0.045983          -0.008854
# Housing_free                                   -0.038389           0.117900
# Housing_own                                     0.029393          -0.075543
# Housing_rent                                   -0.003598          -0.006329
# Saving accounts_little                         -0.015925           0.018063
# Saving accounts_moderate                        0.005748           0.003099
# Saving accounts_quite rich                      0.046996          -0.012590
# Saving accounts_rich                           -0.027375          -0.025883
# Checking account_little                         0.004395          -0.002143
# Checking account_moderate                      -0.033820           0.007446
# Checking account_quite rich                     0.071217           0.013811
# Checking account_rich                          -0.001850          -0.017937
# Purpose_business                               -0.036159          -0.082157
# Purpose_car                                    -0.078496          -0.178351
# Purpose_domestic appliances                     1.000000          -0.027624
# Purpose_education                              -0.027624           1.000000
# Purpose_furniture/equipment                    -0.051867          -0.117849
# Purpose_radio/TV                               -0.068809          -0.156342
# Purpose_repairs                                -0.016546          -0.037595
# Purpose_vacation/others                        -0.012158          -0.027624
# Risk_bad                                        0.008195           0.049527
# Risk_good                                      -0.008195          -0.049527
#
#                              Purpose_furniture/equipment  Purpose_radio/TV  \
# Age                                            -0.128215         -0.047069
# Credit amount                                  -0.011161         -0.183552
# Duration                                       -0.062270         -0.043580
# Sex_female                                      0.100185         -0.009090
# Sex_male                                       -0.100185          0.009090
# Job_0                                          -0.052878         -0.063270
# Job_1                                          -0.021018          0.005258
# Job_2                                           0.064780          0.086322
# Job_3                                          -0.042539         -0.097127
# Housing_free                                   -0.071706         -0.109602
# Housing_own                                    -0.040210          0.135155
# Housing_rent                                    0.105503         -0.070727
# Saving accounts_little                          0.051193         -0.008062
# Saving accounts_moderate                       -0.086433         -0.015568
# Saving accounts_quite rich                      0.006261          0.048983
# Saving accounts_rich                            0.027689         -0.011973
# Checking account_little                         0.062857         -0.039537
# Checking account_moderate                      -0.072057          0.012904
# Checking account_quite rich                     0.009978          0.020335
# Checking account_rich                           0.000514          0.034091
# Purpose_business                               -0.154257         -0.204643
# Purpose_car                                    -0.334869         -0.444250
# Purpose_domestic appliances                    -0.051867         -0.068809
# Purpose_education                              -0.117849         -0.156342
# Purpose_furniture/equipment                     1.000000         -0.293547
# Purpose_radio/TV                               -0.293547          1.000000
# Purpose_repairs                                -0.070587         -0.093644
# Purpose_vacation/others                        -0.051867         -0.068809
# Risk_bad                                        0.021717         -0.106113
# Risk_good                                      -0.021717          0.106113
#
#                              Purpose_repairs  Purpose_vacation/others  \
# Age                                 0.039435                 0.042275
# Credit amount                      -0.034750                 0.122301
# Duration                           -0.022379                 0.104737
# Sex_female                         -0.026935                -0.014375
# Sex_male                            0.026935                 0.014375
# Job_0                               0.070438                 0.046066
# Job_1                               0.044244                -0.032203
# Job_2                              -0.012032                -0.124738
# Job_3                              -0.062579                 0.186806
# Housing_free                        0.013655                 0.079977
# Housing_own                         0.019902                -0.011220
# Housing_rent                       -0.034539                -0.051517
# Saving accounts_little             -0.001170                 0.004790
# Saving accounts_moderate           -0.004978                 0.031613
# Saving accounts_quite rich         -0.010870                -0.028606
# Saving accounts_rich                0.021080                -0.027375
# Checking account_little            -0.019233                -0.032660
# Checking account_moderate           0.032749                 0.065668
# Checking account_quite rich         0.004144                -0.022519
# Checking account_rich              -0.022573                -0.034270
# Purpose_business                   -0.049209                -0.036159
# Purpose_car                        -0.106826                -0.078496
# Purpose_domestic appliances        -0.016546                -0.012158
# Purpose_education                  -0.037595                -0.027624
# Purpose_furniture/equipment        -0.070587                -0.051867
# Purpose_radio/TV                   -0.093644                -0.068809
# Purpose_repairs                     1.000000                -0.016546
# Purpose_vacation/others            -0.016546                 1.000000
# Risk_bad                            0.021082                 0.028259
# Risk_good                          -0.021082                -0.028259
#
#                              Risk_bad  Risk_good
# Age                         -0.089726   0.089726
# Credit amount                0.125613  -0.125613
# Duration                     0.213428  -0.213428
# Sex_female                   0.076624  -0.076624
# Sex_male                    -0.076624   0.076624
# Job_0                        0.006187  -0.006187
# Job_1                       -0.021085   0.021085
# Job_2                       -0.014753   0.014753
# Job_3                        0.041248  -0.041248
# Housing_free                 0.082189  -0.082189
# Housing_own                 -0.135745   0.135745
# Housing_rent                 0.093619  -0.093619
# Saving accounts_little       0.101074  -0.101074
# Saving accounts_moderate    -0.020282   0.020282
# Saving accounts_quite rich  -0.070643   0.070643
# Saving accounts_rich        -0.087482   0.087482
# Checking account_little      0.002179  -0.002179
# Checking account_moderate    0.079595  -0.079595
# Checking account_quite rich -0.077732   0.077732
# Checking account_rich       -0.079732   0.079732
# Purpose_business             0.036675  -0.036675
# Purpose_car                  0.020521  -0.020521
# Purpose_domestic appliances  0.008195  -0.008195
# Purpose_education            0.049527  -0.049527
# Purpose_furniture/equipment  0.021717  -0.021717
# Purpose_radio/TV            -0.106113   0.106113
# Purpose_repairs              0.021082  -0.021082
# Purpose_vacation/others      0.028259  -0.028259
# Risk_bad                     1.000000  -1.000000
# Risk_good                   -1.000000   1.000000
#
# [30 rows x 30 columns]
